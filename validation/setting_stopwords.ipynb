# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/파일위치/pan_qna.csv')

# %%
# !pip install konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 29.9 MB/s eta 0:00:00
# ...

# %%
def tokenize_sentence(sentence):
  tokenized_sentence = []
  tokenized_sentence = kkma.morphs(sentence) # 토큰화
  s = ''
  for t in tokenized_sentence:
    t = re.sub(r"[^가-힣\s]", " ", t)
    s+= t+' '
  return s

# %%
question = [tokenize_sentence(q) for q in df['question']]
df['question'] = question
df.to_csv('/content/drive/MyDrive/파일위치/pan_qna_kkm_no_stopwords.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/파일위치/pan_qna_kkm_no_stopwords.csv')

# %%
result = [q.split(' ') for q in df['question']]
print(result[:3])
# Out:
# [['개인', '금융', '기관', '자금', '대출', '걸', '나', '대출금', '상환', '일련', '사법', '상', '계약', '아야', ''], ['종전', '규정', '허가', '자', '신', '규정', '적용', '매립', '목적', '변경', '대상', '알', '니', '라는', '이유', '행하', '부당', ''], ['군', '복무', '중', '질병', '발병', '악화', '공상', '판정', '전역', '이에', '위원', '회의', '심의', '도', '군복무', '중', '걸', '', '', '질병', '들', '', '', '발병', '치료', '사실', '인정', '다', '면', '행정청', '의무', '기록', '검토', '행하', '위법', '']]

# %%
for l in result:
    while True:
        try:
            l.remove('')
        except:
            break
print(result[:3])
# Out:
# [['개인', '금융', '기관', '자금', '대출', '걸', '나', '대출금', '상환', '일련', '사법', '상', '계약', '아야'], ['종전', '규정', '허가', '자', '신', '규정', '적용', '매립', '목적', '변경', '대상', '알', '니', '라는', '이유', '행하', '부당'], ['군', '복무', '중', '질병', '발병', '악화', '공상', '판정', '전역', '이에', '위원', '회의', '심의', '도', '군복무', '중', '걸', '질병', '들', '발병', '치료', '사실', '인정', '다', '면', '행정청', '의무', '기록', '검토', '행하', '위법']]

# %%
word = []
for r in result:
  for l in r:
    if l != '':
      word.append(l)
print(word[:15])
# Out:
# ['개인', '금융', '기관', '자금', '대출', '걸', '나', '대출금', '상환', '일련', '사법', '상', '계약', '아야', '종전']

# %%
word = pd.Series(word)
stopwords = word.value_counts()[:50]
stopwords =list(stopwords.index)
stopwords.remove('계약')
print(stopwords)
# Out:
# ['하', '의', '에', '이', '는', '을', '가', '되', '를', '있', '여', '으로', '경우', '는가', '수', '아', '로', '그', '은', '고', '제', '것', '지', '에서', '저', '대하', '조', '어', '등', '행위', '관하', '해당', '보', '항', '에게', '및', '과', '받', '와', '없', '의하', '다고', '처분', '않', '또는', '였', '었', '나요', '따르']

# %%
from konlpy.tag import Kkma

kkma = Kkma()

# %%
from tqdm import tqdm
import regex
def remove_stopwords(tokenized_sentence):
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    l = ''
    for s in stopwords_removed_sentence:
        s = re.sub(r"[^가-힣\s]", " ", s)
        l += s +' '
    return l

# %%
question = [remove_stopwords(q) for q in df['question']]
df['question'] = question
df.to_csv('/content/drive/MyDrive/파일위치/pan_qna_kkm_stopwords_to_mode.csv', index=False)
